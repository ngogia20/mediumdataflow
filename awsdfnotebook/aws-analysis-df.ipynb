# %%
# https://towardsdatascience.com/hands-on-introduction-to-delta-lake-with-py-spark-b39460a4b1ae
import oci
from delta import *
import pyspark
from delta.tables import *
get_ipython().run_line_magic('load_ext', 'dataflow.magics')
variableofdatacience=""
# Out:
# The dataflow.magics extension is already loaded. To reload it, use:
#   %reload_ext dataflow.magics

# %%
sessionId='your will session id from createaws.ipynb once executed successfully'
# %use_session -s {sessionId}
# Out:
# Using Active Session .. ocid1.dataflowrun.oc1.ap-mumbai-1.anrg6ljrp77apcqafsukle6wess2zdv2xnxiyrf2nimzdxdigibkdvdbqsyq
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Cluster is ready..
# Starting Spark application..
# <table>
# <tr><th>Session ID</th><th>Kind</th><th>State</th><th>Current session</th></tr><tr><td>ocid1.dataflowapplication.oc1.ap-mumbai-1.anrg6ljrp77apcqajq3y25zy7vfpy4nlgyzwexenweiilnw3amexmdm7id7a</td><td>pyspark</td><td>IN_PROGRESS</td><td><a target="_blank" href="https://console.us-phoenix-1.oraclecloud.com/data-flow/runs/details/ocid1.dataflowrun.oc1.ap-mumbai-1.anrg6ljrp77apcqafsukle6wess2zdv2xnxiyrf2nimzdxdigibkdvdbqsyq?region=ap-mumbai-1">Dataflow Run</a></td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# SparkContext available as 'sc'.

# %%
# %%spark
# print(spark)
#
#
# spark.conf.set("fs.s3a.access.key","Your Access Key of S3"),
# spark.conf.set("fs.s3a.secret.key","Your Secret Key of S3"),
# spark.conf.set("fs.s3a.path.style.access","true"),
# spark.conf.set("fs.s3a.impl","org.apache.hadoop.fs.s3a.S3AFileSystem"),
# spark.conf.set("fs.s3a.endpoint","s3.amazonaws.com")
# spark.conf.set('spark.hadoop.fs.s3a.aws.credentials.provider', 'org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...

# %%
# %%spark
# df_s3 = spark.read.format('csv').option('header','true').load('s3a://airteloraclecdp/testnikesh/')
# df_s3.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----+--------+--------+--------+--------+--------+-------+---------------+-------+-------+-------+-------+-------+----------+-----------+-----------+-----------+-----------+-------+-------+------+--------------+-------+-------+-------+-------+-------+---------+----------+----------+----------+----------+--------------+-------------+---------------+--------------+---------------+--------------+---------------+--------------+---------------+--------------+------------------+-----------------+-------------------+------------------+-------------------+------------------+-------------------+------------------+-------------------+------------------+---------+--------+
# ...
